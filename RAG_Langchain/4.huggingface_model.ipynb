# %%
from langchain_huggingface import HuggingFaceEndpoint
from dotenv import load_dotenv
from langchain_huggingface import ChatHuggingFace
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
import os
hf_token = os.getenv('HUGGINGFACEHUB_API_TOKEN')

# %%
prompt1 = PromptTemplate(
    template='Generate a detailed report on {topic}',
    input_variables=['topic']
)

prompt2 = PromptTemplate(
    template='Generate a 5 pointer summary from the following text \n {text}',
    input_variables=['text']
)

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    temperature=0,
    huggingfacehub_api_token=hf_token,
    task="text-generation", 
)
model = ChatHuggingFace(llm=llm)

# %%
parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

result = chain.invoke({'topic': 'Bermuda Triangle'})

# %%
result
# Out:
# "Here's a 5-pointer summary of the Bermuda Triangle article:\n\n1. **Definition and Location**: The Bermuda Triangle is a region in the western North Atlantic Ocean, bounded by Miami, Florida; San Juan, Puerto Rico; and Bermuda, known for unexplained disappearances of aircraft and ships.\n\n2. **Notable Incidents**: Several high-profile incidents have occurred within the Bermuda Triangle, including the disappearance of Flight 19 in 1945, the sinking of the USS Cyclops in 1918, and the disappearance of the SS Marine Sulphur Queen in 1963.\n\n3. **Theories and Explanations**: Various theories have been proposed to explain the strange occurrences in the Bermuda Triangle, including magnetic anomalies, methane gas, rogue waves, human error, and supernatural forces.\n\n4. **Historical Significance**: The Bermuda Triangle has been associated with strange occurrences for centuries, but it gained widespread attention in the 1940s and 1950s due to a series of high-profile incidents.\n\n5. **Continued Mystery**: Despite numerous investigations and explanations, the Bermuda Triangle remains a mysterious region, with many incidents remaining unexplained and sparking ongoing speculation and debate."
